# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01Bp1Bkc6d3zKNzCRmtTbJQf', container=None, content=[TextBlock(citations=None, text='The best exercises for gaining leg muscle are compound movements that target multiple muscle groups. Here are the most effective ones:\n\n## **Squats** (Most Effective Overall)\n- **Back squats** are considered the gold standard for leg muscle growth\n- They target quads, hamstrings, glutes, and even calves\n- Allow for heavy weight and progressive overload\n- Variations include front squats, goblet squats, and Bulgarian split squats\n\n## **Other Highly Effective Exercises:**\n\n1. **Deadlifts** (especially Romanian deadlifts)\n   - Excellent for hamstrings, glutes, and overall posterior chain\n   \n2. **Lunges**\n   - Great for quads, glutes, and unilateral development\n   - Walking lunges, reverse lunges, and stationary lunges all work well\n\n3. **Leg Press**\n   - Allows heavy loading with less technical demand\n   - Good for quad development\n\n4. **Hip Thrusts**\n   - Best exercise specifically for glute development\n\n## **Key Principles:**\n- **Progressive overload**: Gradually increase weight or reps over time\n- **Volume**: Multiple sets (3-5) of 6-12 reps is ideal for muscle growth\n- **Frequency**: Train legs 2-3 times per week\n- **Nutrition**: Adequate protein (1.6-2.2g per kg body weight) and caloric surplus\n\nFor most people, building a leg routine around **squats and deadlift variations**, supplemented with accessory exercises like lunges and leg press, will produce the best muscle-building results.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=2228, output_tokens=369, server_tool_use=None, service_tier='standard'))
